# %%
import pandas as pd
reviews_df = pd.read_csv('C:/Develop/深圳42/data/sn_reviews.csv')
reviews_df.head()
# Out:
#                                                 商品标题        价格  \
# 0   自营 超级新品 格力（GREE）1.5匹 变频 KFR-35GW/(35583)FNCb-...  ¥2899.00
# 1   自营 超级新品 格力（GREE）1.5匹 变频 KFR-35GW/(35583)FNCb-...  ¥2899.00
# 2   自营 超级新品 格力（GREE）1.5匹 变频 KFR-35GW/(35583)FNCb-...  ¥2899.00
# 3   自营 超级新品 格力（GREE）1.5匹 变频 KFR-35GW/(35583)FNCb-...  ¥2899.00
# 4   自营 超级新品 格力（GREE）1.5匹 变频 KFR-35GW/(35583)FNCb-...  ¥2899.00
#
#                                              商品页面URL  好评率  \
# 0  https://product.suning.com/0000000000/16454870...  99%
# 1  https://product.suning.com/0000000000/16454870...  99%
# 2  https://product.suning.com/0000000000/16454870...  99%
# 3  https://product.suning.com/0000000000/16454870...  99%
# 4  https://product.suning.com/0000000000/16454870...  99%
#
#                                                 大家印象  评价数量   会员名称 评价标签  \
# 0  \n \n 服务很好(309)\n \n 安装及时(307)\n \n 包装完好(306)\...   NaN  1***9  NaN
# 1  \n \n 服务很好(309)\n \n 安装及时(307)\n \n 包装完好(306)\...   NaN  1***1  NaN
# ...

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   商品标题     1142 non-null   object
#  1   价格       1142 non-null   object
#  2   商品页面URL  1142 non-null   object
#  3   好评率      652 non-null    object
#  4   大家印象     652 non-null    object
#  5   评价数量     0 non-null      float64
#  6   会员名称     1142 non-null   object
#  7   评价标签     558 non-null    object
#  8   评价内容     1142 non-null   object
#  9   购买产品     0 non-null      float64
#  10  卖家       0 non-null      float64
#  11  评价星级     1142 non-null   object
#  12  评价图片URL  501 non-null    object
#  13  追评内容     16 non-null     object
#  14  追评图片URL  8 non-null      object
#  15  追评时间     16 non-null     object
#  16  评价设备系统   0 non-null      float64
#  17  采集时间     1142 non-null   object
# dtypes: float64(4), object(14)
# memory usage: 160.7+ KB

# %%
reviews_df['评价星级'].value_counts()
# Out:
# 5星      951
# 1星      101
# 3星       49
# 2星       25
# 56px     16
# Name: 评价星级, dtype: int64

# %%
import jieba

# %%
reviews_content = reviews_df['评价内容'][0]

# %%
reviews_content
# Out:
# '\n 货已收到，送货师傅服务很好，包装完好，没有损伤，暂时还没安装，等安装完再来补充\n '

# %%
jieba.lcut(reviews_content)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.920 seconds.
# Prefix dict has been built successfully.
# ['\n',
#  ' ',
#  '货已',
#  '收到',
#  '，',
#  '送货',
#  '师傅',
#  '服务',
#  '很',
#  '好',
#  '，',
#  '包装',
#  '完好',
#  '，',
#  '没有',
#  '损伤',
#  '，',
#  '暂时',
#  '还',
#  '没',
#  '安装',
#  '，',
#  '等',
#  '安装',
#  '完再',
#  '来',
#  '补充',
#  '\n',
#  ' ']
