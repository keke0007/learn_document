# %%
import pandas as pd
df = pd.read_csv('C:/Develop/深圳42/data/LJdata.csv')

# %% [markdown]
# ## 访问行索引和列名

# %%
df.head()
# Out:
#       区域      地址    户型   面积    价格  朝向        更新时间  看房人数
# 0   燕莎租房     新源街  2室1厅   50  5800   南  2017.07.21    26
# 1   望京租房    澳洲康都  2室1厅   79  7800   东  2017.07.23    33
# 2  广安门租房    远见名苑  2室1厅   86  8000   东  2017.07.20    34
# 3  天通苑租房  天通苑北一区  2室1厅  103  5300  东南  2017.07.25    30
# 4  团结湖租房   团结湖北口  2室1厅   63  6400   南  2017.07.26    30

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2760, step=1)

# %%
df.columns
# Out:
# Index(['区域', '地址', '户型', '面积', '价格', '朝向', '更新时间', '看房人数'], dtype='object')

# %%
# 修改索引   某一列的值设置为index
df.set_index('地址', inplace=True)

# %%
df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.reset_index(inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:6361, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6355         if lab is not None:
#    6356             # if we have the codes, extract the values with a mask
#    6357             level_values = algorithms.take(
# ...

# %%
df.columns
# Out:
# Index(['level_0', 'index', '地址', '区域', '户型', '面积', '价格', '朝向', '更新时间', '看房人数'], dtype='object')

# %%
df.drop(['level_0', 'index'],axis=1,inplace=True)

# %%
# 修改列名
df.index[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 修改列名
# ----> 2 df.index[0] = 10
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5302, in Index.__setitem__(self, key, value)
#    5300 @final
#    5301 def __setitem__(self, key, value):
# -> 5302     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
df.columns[0] ='address'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.columns[0] ='address'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5302, in Index.__setitem__(self, key, value)
#    5300 @final
#    5301 def __setitem__(self, key, value):
# -> 5302     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
df.columns = ['address', '区域', '户型', '面积', '价格', '朝向', '更新时间', '看房人数']
df
# Out:
#      address     区域    户型   面积     价格  朝向        更新时间  看房人数
# 0        新源街   燕莎租房  2室1厅   50   5800   南  2017.07.21    26
# 1       澳洲康都   望京租房  2室1厅   79   7800   东  2017.07.23    33
# 2       远见名苑  广安门租房  2室1厅   86   8000   东  2017.07.20    34
# 3     天通苑北一区  天通苑租房  2室1厅  103   5300  东南  2017.07.25    30
# 4      团结湖北口  团结湖租房  2室1厅   63   6400   南  2017.07.26    30
# ...      ...    ...   ...  ...    ...  ..         ...   ...
# 2755   天鹅湾北区   朝青租房  1室1厅   50   9500   南  2017.07.27    13
# 2756     水星园  太阳宫租房  1室1厅   68   9500   北  2017.07.24    14
# 2757    莲花小区  六里桥租房  2室1厅   84   7200  西南  2017.07.26     7
# 2758  中海紫御公馆  陶然亭租房  2室2厅   91  12000   南  2017.07.26     6
# 2759     曙光里  三元桥租房  2室1厅   62   6200   南  2017.07.25    19
#
# [2760 rows x 8 columns]

# %%
temp_df = df.head().copy()
temp_df
# Out:
#   address     区域    户型   面积    价格  朝向        更新时间  看房人数
# 0     新源街   燕莎租房  2室1厅   50  5800   南  2017.07.21    26
# 1    澳洲康都   望京租房  2室1厅   79  7800   东  2017.07.23    33
# 2    远见名苑  广安门租房  2室1厅   86  8000   东  2017.07.20    34
# 3  天通苑北一区  天通苑租房  2室1厅  103  5300  东南  2017.07.25    30
# 4   团结湖北口  团结湖租房  2室1厅   63  6400   南  2017.07.26    30

# %%
temp_df.index=['a','b','c','d','e']

# %%
temp_df.index[0] = 'A'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 temp_df.index[0] = 'A'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5302, in Index.__setitem__(self, key, value)
#    5300 @final
#    5301 def __setitem__(self, key, value):
# -> 5302     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# rename方法

# %%
temp_df.rename(index={'a':'A'},columns={'address':'地址'},inplace=True)

# %%
temp_df
# Out:
#        地址     区域    户型   面积    价格  朝向        更新时间  看房人数
# A     新源街   燕莎租房  2室1厅   50  5800   南  2017.07.21    26
# b    澳洲康都   望京租房  2室1厅   79  7800   东  2017.07.23    33
# c    远见名苑  广安门租房  2室1厅   86  8000   东  2017.07.20    34
# d  天通苑北一区  天通苑租房  2室1厅  103  5300  东南  2017.07.25    30
# e   团结湖北口  团结湖租房  2室1厅   63  6400   南  2017.07.26    30

# %%
df = pd.read_csv('C:/Develop/深圳42/data/LJdata.csv')
df
# Out:
#          区域      地址    户型   面积     价格  朝向        更新时间  看房人数
# 0      燕莎租房     新源街  2室1厅   50   5800   南  2017.07.21    26
# 1      望京租房    澳洲康都  2室1厅   79   7800   东  2017.07.23    33
# 2     广安门租房    远见名苑  2室1厅   86   8000   东  2017.07.20    34
# 3     天通苑租房  天通苑北一区  2室1厅  103   5300  东南  2017.07.25    30
# 4     团结湖租房   团结湖北口  2室1厅   63   6400   南  2017.07.26    30
# ...     ...     ...   ...  ...    ...  ..         ...   ...
# 2755   朝青租房   天鹅湾北区  1室1厅   50   9500   南  2017.07.27    13
# 2756  太阳宫租房     水星园  1室1厅   68   9500   北  2017.07.24    14
# 2757  六里桥租房    莲花小区  2室1厅   84   7200  西南  2017.07.26     7
# 2758  陶然亭租房  中海紫御公馆  2室2厅   91  12000   南  2017.07.26     6
# 2759  三元桥租房     曙光里  2室1厅   62   6200   南  2017.07.25    19
#
# [2760 rows x 8 columns]

# %%
# 读数据的时候直接指定哪一列作为索引
df = pd.read_csv('C:/Develop/深圳42/data/LJdata.csv',index_col='地址')
df.reset_index()
# Out:
#           地址     区域    户型   面积     价格  朝向        更新时间  看房人数
# 0        新源街   燕莎租房  2室1厅   50   5800   南  2017.07.21    26
# 1       澳洲康都   望京租房  2室1厅   79   7800   东  2017.07.23    33
# 2       远见名苑  广安门租房  2室1厅   86   8000   东  2017.07.20    34
# 3     天通苑北一区  天通苑租房  2室1厅  103   5300  东南  2017.07.25    30
# 4      团结湖北口  团结湖租房  2室1厅   63   6400   南  2017.07.26    30
# ...      ...    ...   ...  ...    ...  ..         ...   ...
# 2755   天鹅湾北区   朝青租房  1室1厅   50   9500   南  2017.07.27    13
# 2756     水星园  太阳宫租房  1室1厅   68   9500   北  2017.07.24    14
# 2757    莲花小区  六里桥租房  2室1厅   84   7200  西南  2017.07.26     7
# 2758  中海紫御公馆  陶然亭租房  2室2厅   91  12000   南  2017.07.26     6
# 2759     曙光里  三元桥租房  2室1厅   62   6200   南  2017.07.25    19
#
# [2760 rows x 8 columns]
